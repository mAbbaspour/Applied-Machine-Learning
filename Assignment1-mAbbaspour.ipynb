# %% [markdown]
# # Assignment1 by Mohmmadjavd Abbas pour

# %%
import sys
print(sys.version)
# Out:
# 3.6.13 |Anaconda, Inc.| (default, Mar 16 2021, 11:37:27) [MSC v.1916 64 bit (AMD64)]

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
   j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -1.058935  1.423642  1.759184 -1.204316
# 1 -1.116444  0.523670  0.243579 -0.690450
# 2 -0.786312  0.710607  0.089137 -0.359773
# 3 -1.978093  1.476578 -1.682419  0.934124
# 4 -1.255037  1.033758 -0.066822 -0.586397
# 5 -1.358677 -1.211463  0.394627  1.680975
# 6  0.225604 -0.117100 -0.468515  0.157760
# 7  1.064876  0.542589  0.675887  1.412362
# 8 -1.811333 -0.165050  0.939672 -0.616779
# 9 -1.849695 -1.123583 -0.351691  0.049701
#
# -> Execution Time = 17.147106409072876 in Seconds <-
